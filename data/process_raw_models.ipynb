# %%
import glob
import pandas as pd

# %%
files = glob.glob('raw_models/*.csv')

# %%
data = pd.read_csv(files[0])
data.columns
# Out:
# Index(['path', 'stability', 'n_ML_phases', 'FeH_init', 'Z_init',
#        'termination_code', 'PRLODays', 'PoverPMax', 'TtipMyr', 'GalAgeMyr',
#        'AgeBinNum', 'DeltaTBin', 'P_init', 'P_final', 'a_final', 'M1_init',
#        'M1_final', 'M2_init', 'M2_final', 'M2_accreted', 'q_init', 'q_final',
#        'delta_max', 'M1_HeIgnition', 'M1core_HeIgnition', 'M1env_HeIgnition',
#        'age_HeIgnition', 'duration_HeCoreBurning', 'logg_HeCoreBurning',
#        'teff_HeCoreBurning', 'rad_HeCoreBurning', 'M1_HeCoreBurning',
#        'M1core_HeCoreBurning', 'M1env_HeCoreBurning', 'logg2_HeCoreBurning',
#        'teff2_HeCoreBurning', 'rad2_HeCoreBurning', 'duration_HeShellBurning',
#        'M1_HeShellBurning', 'M1core_HeShellBurning', 'M1env_HeShellBurning',
#        'log10_J_div_Jdot_div_P__min', 'RL1_max', 'R1_max', 'Mdot_max',
#        'Jdot_max', 'teff_MLstart', 'logg_MLstart', 'rad_MLstart',
#        'teff2_MLstart', 'logg2_MLstart', 'rad2_MLstart', 'ML_duration',
#        'M1_MLend', 'M1core_MLend', 'M1env_MLend', 'M1core_ML_rate',
#        'rl_1__final', 'rl_2__final', 'M1_Mdotmax', 'M1core_Mdotmax',
#        'M1env_Mdotmax', 'M1_CEstart', 'M2_CEstart', 'P_CEstart', 'q_CEstart',
#        'HeCoreBurning', 'sdA', 'sdB', 'sdO', 'He-WD', 'stability_criterion',
#        'stability_limit', 'ce_profile_name', 'ce_formalism', 'ce_parameters',
#        'error_flags', 'product', 'G_HeCoreBurning', 'BP_HeCoreBurning',
#        'RP_HeCoreBurning', 'BP-RP_HeCoreBurning', 'binary_type',
#        'observable_sd', 'G_MLstart', 'BP_MLstart', 'RP_MLstart',
#        'BP-RP_MLstart', 'RV_K1', 'RV_K2', 'reflection_amp',
#        'HeCoreBurning_prob'],
#       dtype='object')

# %%
usecols = ['stability', 'FeH_init', 'termination_code', 
        'P_init', 'P_final', 'M1_init',
       'M1_final', 'M2_init', 'M2_final', 'q_init', 'q_final',
       'duration_HeCoreBurning', 'logg_HeCoreBurning',
       'teff_HeCoreBurning', 'rad_HeCoreBurning', 'M1_HeCoreBurning',
       'M1core_HeCoreBurning', 'M1env_HeCoreBurning', 'logg2_HeCoreBurning',
       'teff2_HeCoreBurning', 'rad2_HeCoreBurning', 
       'log10_J_div_Jdot_div_P__min','Mdot_max', 'Jdot_max', 'delta_max', 
       'rl_1__final', 'rl_2__final', 
       'stability_criterion', 'stability_limit', 'ce_parameters',
       'error_flags', 'product', 'G_HeCoreBurning', 'BP_HeCoreBurning',
       'RP_HeCoreBurning', 'BP-RP_HeCoreBurning', 'binary_type',
       'observable_sd', 'RV_K1', 'RV_K2', 'reflection_amp']

dfs = []
all_files = len(files)
for i, filename in enumerate(files):
    print(i+1, '/', all_files, filename)
    df = pd.read_csv(filename, usecols=usecols)
    newfile = filename.replace('raw_models', 'models').replace('.csv', '_reduced.csv')
    df.to_csv(newfile, index=False)
# Out:
# 1 / 162 raw_models/sdBShortP_large_jdotp_30_alphaCE_0.20_alphaTH_0_ce_applied.csv
# 2 / 162 raw_models/sdBShortP_large_mdot_-1_alphaCE_0.10_alphaTH_0.10_ce_applied.csv
# 3 / 162 raw_models/sdBShortP_large_mdot_-3_alphaCE_1.50_alphaTH_0_ce_applied.csv
# 4 / 162 raw_models/sdBShortP_large_jdotp_3_alphaCE_2.00_alphaTH_0_ce_applied.csv
# 5 / 162 raw_models/sdBShortP_large_jdotp_10_alphaCE_0.10_alphaTH_0_ce_applied.csv
# 6 / 162 raw_models/sdBShortP_large_mdot_0_alphaCE_0.70_alphaTH_0_ce_applied.csv
# 7 / 162 raw_models/sdBShortP_large_mdot_0_alphaCE_2.00_alphaTH_0_ce_applied.csv
# 8 / 162 raw_models/sdBShortP_large_mdot_0_alphaCE_0.20_alphaTH_0.20_ce_applied.csv
# 9 / 162 raw_models/sdBShortP_large_jdotp_30_alphaCE_1.00_alphaTH_1.00_ce_applied.csv
# 10 / 162 raw_models/sdBShortP_large_mdot_-1_alphaCE_0.70_alphaTH_0_ce_applied.csv
# 11 / 162 raw_models/sdBShortP_large_mdot_-3_alphaCE_1.50_alphaTH_1.50_ce_applied.csv
# 12 / 162 raw_models/sdBShortP_large_mdot_-2_alphaCE_1.50_alphaTH_1.50_ce_applied.csv
# 13 / 162 raw_models/sdBShortP_large_jdotp_3_alphaCE_0.50_alphaTH_0.50_ce_applied.csv
# 14 / 162 raw_models/sdBShortP_large_jdotp_30_alphaCE_0.30_alphaTH_0.30_ce_applied.csv
# 15 / 162 raw_models/sdBShortP_large_jdotp_10_alphaCE_1.50_alphaTH_1.50_ce_applied.csv
# 16 / 162 raw_models/sdBShortP_large_jdotp_3_alphaCE_0.10_alphaTH_0.10_ce_applied.csv
# 17 / 162 raw_models/sdBShortP_large_jdotp_3_alphaCE_0.30_alphaTH_0_ce_applied.csv
# 18 / 162 raw_models/sdBShortP_large_mdot_-2_alphaCE_0.70_alphaTH_0.70_ce_applied.csv
# 19 / 162 raw_models/sdBShortP_large_jdotp_10_alphaCE_0.10_alphaTH_0.10_ce_applied.csv
# 20 / 162 raw_models/sdBShortP_large_jdotp_100_alphaCE_0.50_alphaTH_0_ce_applied.csv
# 21 / 162 raw_models/sdBShortP_large_mdot_-1_alphaCE_0.70_alphaTH_0.70_ce_applied.csv
# 22 / 162 raw_models/sdBShortP_large_jdotp_100_alphaCE_0.50_alphaTH_0.50_ce_applied.csv
# 23 / 162 raw_models/sdBShortP_large_mdot_0_alphaCE_1.50_alphaTH_1.50_ce_applied.csv
# 24 / 162 raw_models/sdBShortP_large_mdot_-2_alphaCE_0.30_alphaTH_0.30_ce_applied.csv
# 25 / 162 raw_models/sdBShortP_large_mdot_-2_alphaCE_1.00_alphaTH_1.00_ce_applied.csv
# 26 / 162 raw_models/sdBShortP_large_jdotp_100_alphaCE_0.10_alphaTH_0.10_ce_applied.csv
# 27 / 162 raw_models/sdBShortP_large_jdotp_100_alphaCE_1.50_alphaTH_1.50_ce_applied.csv
# 28 / 162 raw_models/sdBShortP_large_mdot_-1_alphaCE_0.10_alphaTH_0_ce_applied.csv
# 29 / 162 raw_models/sdBShortP_large_mdot_-3_alphaCE_0.10_alphaTH_0_ce_applied.csv
# 30 / 162 raw_models/sdBShortP_large_mdot_0_alphaCE_0.30_alphaTH_0_ce_applied.csv
# 31 / 162 raw_models/sdBShortP_large_jdotp_10_alphaCE_0.30_alphaTH_0.30_ce_applied.csv
# 32 / 162 raw_models/sdBShortP_large_mdot_-3_alphaCE_2.00_alphaTH_2.00_ce_applied.csv
# 33 / 162 raw_models/sdBShortP_large_jdotp_30_alphaCE_2.00_alphaTH_0_ce_applied.csv
# 34 / 162 raw_models/sdBShortP_large_mdot_-3_alphaCE_0.30_alphaTH_0.30_ce_applied.csv
# 35 / 162 raw_models/sdBShortP_large_jdotp_1_alphaCE_2.00_alphaTH_2.00_ce_applied.csv
# 36 / 162 raw_models/sdBShortP_large_jdotp_30_alphaCE_1.50_alphaTH_0_ce_applied.csv
# 37 / 162 raw_models/sdBShortP_large_jdotp_1_alphaCE_0.10_alphaTH_0_ce_applied.csv
# 38 / 162 raw_models/sdBShortP_large_jdotp_100_alphaCE_0.20_alphaTH_0_ce_applied.csv
# 39 / 162 raw_models/sdBShortP_large_jdotp_3_alphaCE_1.50_alphaTH_0_ce_applied.csv
# 40 / 162 raw_models/sdBShortP_large_jdotp_10_alphaCE_0.70_alphaTH_0_ce_applied.csv
# 41 / 162 raw_models/sdBShortP_large_mdot_-3_alphaCE_0.70_alphaTH_0_ce_applied.csv
# 42 / 162 raw_models/sdBShortP_large_mdot_-3_alphaCE_1.00_alphaTH_1.00_ce_applied.csv
# 43 / 162 raw_models/sdBShortP_large_jdotp_10_alphaCE_0.70_alphaTH_0.70_ce_applied.csv
# 44 / 162 raw_models/sdBShortP_large_mdot_-3_alphaCE_0.30_alphaTH_0_ce_applied.csv
# 45 / 162 raw_models/sdBShortP_large_mdot_-2_alphaCE_2.00_alphaTH_0_ce_applied.csv
# 46 / 162 raw_models/sdBShortP_large_jdotp_30_alphaCE_1.50_alphaTH_1.50_ce_applied.csv
# 47 / 162 raw_models/sdBShortP_large_jdotp_1_alphaCE_2.00_alphaTH_0_ce_applied.csv
# 48 / 162 raw_models/sdBShortP_large_jdotp_100_alphaCE_0.70_alphaTH_0.70_ce_applied.csv
# 49 / 162 raw_models/sdBShortP_large_mdot_-2_alphaCE_2.00_alphaTH_2.00_ce_applied.csv
# 50 / 162 raw_models/sdBShortP_large_mdot_-3_alphaCE_0.15_alphaTH_0_ce_applied.csv
# 51 / 162 raw_models/sdBShortP_large_jdotp_10_alphaCE_0.50_alphaTH_0_ce_applied.csv
# 52 / 162 raw_models/sdBShortP_large_mdot_0_alphaCE_0.50_alphaTH_0_ce_applied.csv
# 53 / 162 raw_models/sdBShortP_large_mdot_-2_alphaCE_0.10_alphaTH_0_ce_applied.csv
# 54 / 162 raw_models/sdBShortP_large_jdotp_1_alphaCE_1.50_alphaTH_0_ce_applied.csv
# 55 / 162 raw_models/sdBShortP_large_jdotp_100_alphaCE_0.30_alphaTH_0.30_ce_applied.csv
# 56 / 162 raw_models/sdBShortP_large_jdotp_30_alphaCE_1.00_alphaTH_0_ce_applied.csv
# 57 / 162 raw_models/sdBShortP_large_jdotp_100_alphaCE_1.00_alphaTH_0_ce_applied.csv
# 58 / 162 raw_models/sdBShortP_large_jdotp_3_alphaCE_2.00_alphaTH_2.00_ce_applied.csv
# 59 / 162 raw_models/sdBShortP_large_mdot_0_alphaCE_0.10_alphaTH_0_ce_applied.csv
# 60 / 162 raw_models/sdBShortP_large_jdotp_10_alphaCE_0.50_alphaTH_0.50_ce_applied.csv
# 61 / 162 raw_models/sdBShortP_large_mdot_-1_alphaCE_2.00_alphaTH_0_ce_applied.csv
# 62 / 162 raw_models/sdBShortP_large_jdotp_10_alphaCE_2.00_alphaTH_2.00_ce_applied.csv
# 63 / 162 raw_models/sdBShortP_large_jdotp_1_alphaCE_0.30_alphaTH_0.30_ce_applied.csv
# 64 / 162 raw_models/sdBShortP_large_mdot_-3_alphaCE_0.50_alphaTH_0.50_ce_applied.csv
# 65 / 162 raw_models/sdBShortP_large_jdotp_3_alphaCE_1.00_alphaTH_0_ce_applied.csv
# 66 / 162 raw_models/sdBShortP_large_jdotp_30_alphaCE_0.15_alphaTH_0_ce_applied.csv
# 67 / 162 raw_models/sdBShortP_large_mdot_0_alphaCE_0.70_alphaTH_0.70_ce_applied.csv
# 68 / 162 raw_models/sdBShortP_large_jdotp_3_alphaCE_1.50_alphaTH_1.50_ce_applied.csv
# 69 / 162 raw_models/sdBShortP_large_jdotp_3_alphaCE_0.30_alphaTH_0.30_ce_applied.csv
# 70 / 162 raw_models/sdBShortP_large_jdotp_10_alphaCE_1.50_alphaTH_0_ce_applied.csv
# 71 / 162 raw_models/sdBShortP_large_mdot_-1_alphaCE_0.50_alphaTH_0.50_ce_applied.csv
# 72 / 162 raw_models/sdBShortP_large_jdotp_3_alphaCE_0.10_alphaTH_0_ce_applied.csv
# 73 / 162 raw_models/sdBShortP_large_mdot_0_alphaCE_0.30_alphaTH_0.30_ce_applied.csv
# 74 / 162 raw_models/sdBShortP_large_jdotp_3_alphaCE_0.70_alphaTH_0_ce_applied.csv
# 75 / 162 raw_models/sdBShortP_large_mdot_-2_alphaCE_0.15_alphaTH_0_ce_applied.csv
# 76 / 162 raw_models/sdBShortP_large_mdot_0_alphaCE_0.15_alphaTH_0.15_ce_applied.csv
# 77 / 162 raw_models/sdBShortP_large_jdotp_100_alphaCE_1.00_alphaTH_1.00_ce_applied.csv
# 78 / 162 raw_models/sdBShortP_large_jdotp_10_alphaCE_2.00_alphaTH_0_ce_applied.csv
# 79 / 162 raw_models/sdBShortP_large_jdotp_100_alphaCE_0.15_alphaTH_0_ce_applied.csv
# 80 / 162 raw_models/sdBShortP_large_jdotp_1_alphaCE_0.70_alphaTH_0_ce_applied.csv
# 81 / 162 raw_models/sdBShortP_large_jdotp_10_alphaCE_0.15_alphaTH_0_ce_applied.csv
# 82 / 162 raw_models/sdBShortP_large_mdot_-2_alphaCE_0.30_alphaTH_0_ce_applied.csv
# 83 / 162 raw_models/sdBShortP_large_mdot_0_alphaCE_0.50_alphaTH_0.50_ce_applied.csv
# 84 / 162 raw_models/sdBShortP_large_jdotp_30_alphaCE_0.10_alphaTH_0_ce_applied.csv
# 85 / 162 raw_models/sdBShortP_large_mdot_0_alphaCE_1.00_alphaTH_0_ce_applied.csv
# 86 / 162 raw_models/sdBShortP_large_mdot_-3_alphaCE_2.00_alphaTH_0_ce_applied.csv
# 87 / 162 raw_models/sdBShortP_large_mdot_-2_alphaCE_1.50_alphaTH_0_ce_applied.csv
# 88 / 162 raw_models/sdBShortP_large_jdotp_3_alphaCE_0.20_alphaTH_0_ce_applied.csv
# 89 / 162 raw_models/sdBShortP_large_jdotp_1_alphaCE_1.00_alphaTH_1.00_ce_applied.csv
# 90 / 162 raw_models/sdBShortP_large_jdotp_10_alphaCE_0.20_alphaTH_0.20_ce_applied.csv
# 91 / 162 raw_models/sdBShortP_large_mdot_0_alphaCE_1.00_alphaTH_1.00_ce_applied.csv
# 92 / 162 raw_models/sdBShortP_large_jdotp_30_alphaCE_0.50_alphaTH_0.50_ce_applied.csv
# 93 / 162 raw_models/sdBShortP_large_jdotp_3_alphaCE_0.20_alphaTH_0.20_ce_applied.csv
# 94 / 162 raw_models/sdBShortP_large_jdotp_1_alphaCE_0.15_alphaTH_0_ce_applied.csv
# 95 / 162 raw_models/sdBShortP_large_jdotp_30_alphaCE_0.10_alphaTH_0.10_ce_applied.csv
# 96 / 162 raw_models/sdBShortP_large_jdotp_1_alphaCE_0.50_alphaTH_0.50_ce_applied.csv
# 97 / 162 raw_models/sdBShortP_large_mdot_-1_alphaCE_0.20_alphaTH_0.20_ce_applied.csv
# 98 / 162 raw_models/sdBShortP_large_jdotp_100_alphaCE_0.70_alphaTH_0_ce_applied.csv
# 99 / 162 raw_models/sdBShortP_large_jdotp_10_alphaCE_0.15_alphaTH_0.15_ce_applied.csv
# 100 / 162 raw_models/sdBShortP_large_mdot_-2_alphaCE_0.70_alphaTH_0_ce_applied.csv
# 101 / 162 raw_models/sdBShortP_large_jdotp_30_alphaCE_0.15_alphaTH_0.15_ce_applied.csv
# 102 / 162 raw_models/sdBShortP_large_jdotp_1_alphaCE_0.10_alphaTH_0.10_ce_applied.csv
# 103 / 162 raw_models/sdBShortP_large_jdotp_30_alphaCE_2.00_alphaTH_2.00_ce_applied.csv
# 104 / 162 raw_models/sdBShortP_large_jdotp_3_alphaCE_0.15_alphaTH_0_ce_applied.csv
# 105 / 162 raw_models/sdBShortP_large_jdotp_100_alphaCE_0.15_alphaTH_0.15_ce_applied.csv
# 106 / 162 raw_models/sdBShortP_large_jdotp_3_alphaCE_0.15_alphaTH_0.15_ce_applied.csv
# 107 / 162 raw_models/sdBShortP_large_jdotp_3_alphaCE_0.50_alphaTH_0_ce_applied.csv
# 108 / 162 raw_models/sdBShortP_large_mdot_-2_alphaCE_0.20_alphaTH_0_ce_applied.csv
# 109 / 162 raw_models/sdBShortP_large_jdotp_1_alphaCE_0.50_alphaTH_0_ce_applied.csv
# 110 / 162 raw_models/sdBShortP_large_mdot_-2_alphaCE_1.00_alphaTH_0_ce_applied.csv
# 111 / 162 raw_models/sdBShortP_large_mdot_0_alphaCE_0.15_alphaTH_0_ce_applied.csv
# 112 / 162 raw_models/sdBShortP_large_jdotp_10_alphaCE_0.20_alphaTH_0_ce_applied.csv
# 113 / 162 raw_models/sdBShortP_large_mdot_-3_alphaCE_0.15_alphaTH_0.15_ce_applied.csv
# 114 / 162 raw_models/sdBShortP_large_jdotp_100_alphaCE_0.10_alphaTH_0_ce_applied.csv
# 115 / 162 raw_models/sdBShortP_large_mdot_-2_alphaCE_0.10_alphaTH_0.10_ce_applied.csv
# 116 / 162 raw_models/sdBShortP_large_mdot_-1_alphaCE_0.20_alphaTH_0_ce_applied.csv
# 117 / 162 raw_models/sdBShortP_large_jdotp_1_alphaCE_0.20_alphaTH_0.20_ce_applied.csv
# 118 / 162 raw_models/sdBShortP_large_mdot_-2_alphaCE_0.15_alphaTH_0.15_ce_applied.csv
# 119 / 162 raw_models/sdBShortP_large_jdotp_30_alphaCE_0.20_alphaTH_0.20_ce_applied.csv
# 120 / 162 raw_models/sdBShortP_large_mdot_-2_alphaCE_0.50_alphaTH_0.50_ce_applied.csv
# 121 / 162 raw_models/sdBShortP_large_jdotp_100_alphaCE_2.00_alphaTH_2.00_ce_applied.csv
# 122 / 162 raw_models/sdBShortP_large_jdotp_3_alphaCE_1.00_alphaTH_1.00_ce_applied.csv
# 123 / 162 raw_models/sdBShortP_large_mdot_0_alphaCE_1.50_alphaTH_0_ce_applied.csv
# 124 / 162 raw_models/sdBShortP_large_jdotp_1_alphaCE_0.20_alphaTH_0_ce_applied.csv
# 125 / 162 raw_models/sdBShortP_large_jdotp_100_alphaCE_0.20_alphaTH_0.20_ce_applied.csv
# 126 / 162 raw_models/sdBShortP_large_jdotp_10_alphaCE_1.00_alphaTH_0_ce_applied.csv
# 127 / 162 raw_models/sdBShortP_large_mdot_-1_alphaCE_1.50_alphaTH_0_ce_applied.csv
# 128 / 162 raw_models/sdBShortP_large_jdotp_100_alphaCE_1.50_alphaTH_0_ce_applied.csv
# 129 / 162 raw_models/sdBShortP_large_mdot_-3_alphaCE_0.20_alphaTH_0_ce_applied.csv
# 130 / 162 raw_models/sdBShortP_large_mdot_-1_alphaCE_1.00_alphaTH_0_ce_applied.csv
# 131 / 162 raw_models/sdBShortP_large_jdotp_1_alphaCE_1.50_alphaTH_1.50_ce_applied.csv
# 132 / 162 raw_models/sdBShortP_large_mdot_-2_alphaCE_0.50_alphaTH_0_ce_applied.csv
# 133 / 162 raw_models/sdBShortP_large_mdot_-2_alphaCE_0.20_alphaTH_0.20_ce_applied.csv
# 134 / 162 raw_models/sdBShortP_large_jdotp_30_alphaCE_0.30_alphaTH_0_ce_applied.csv
# 135 / 162 raw_models/sdBShortP_large_mdot_-1_alphaCE_0.30_alphaTH_0_ce_applied.csv
# 136 / 162 raw_models/sdBShortP_large_mdot_-1_alphaCE_2.00_alphaTH_2.00_ce_applied.csv
# 137 / 162 raw_models/sdBShortP_large_mdot_-1_alphaCE_0.15_alphaTH_0_ce_applied.csv
# 138 / 162 raw_models/sdBShortP_large_mdot_-1_alphaCE_1.00_alphaTH_1.00_ce_applied.csv
# 139 / 162 raw_models/sdBShortP_large_mdot_-1_alphaCE_0.15_alphaTH_0.15_ce_applied.csv
# 140 / 162 raw_models/sdBShortP_large_mdot_-1_alphaCE_0.50_alphaTH_0_ce_applied.csv
# 141 / 162 raw_models/sdBShortP_large_jdotp_100_alphaCE_2.00_alphaTH_0_ce_applied.csv
# 142 / 162 raw_models/sdBShortP_large_mdot_-1_alphaCE_1.50_alphaTH_1.50_ce_applied.csv
# 143 / 162 raw_models/sdBShortP_large_mdot_0_alphaCE_2.00_alphaTH_2.00_ce_applied.csv
# 144 / 162 raw_models/sdBShortP_large_mdot_-1_alphaCE_0.30_alphaTH_0.30_ce_applied.csv
# 145 / 162 raw_models/sdBShortP_large_jdotp_1_alphaCE_0.30_alphaTH_0_ce_applied.csv
# 146 / 162 raw_models/sdBShortP_large_jdotp_10_alphaCE_1.00_alphaTH_1.00_ce_applied.csv
# 147 / 162 raw_models/sdBShortP_large_jdotp_1_alphaCE_0.70_alphaTH_0.70_ce_applied.csv
# 148 / 162 raw_models/sdBShortP_large_mdot_-3_alphaCE_0.70_alphaTH_0.70_ce_applied.csv
# 149 / 162 raw_models/sdBShortP_large_jdotp_1_alphaCE_0.15_alphaTH_0.15_ce_applied.csv
# 150 / 162 raw_models/sdBShortP_large_mdot_0_alphaCE_0.20_alphaTH_0_ce_applied.csv
# 151 / 162 raw_models/sdBShortP_large_jdotp_10_alphaCE_0.30_alphaTH_0_ce_applied.csv
# 152 / 162 raw_models/sdBShortP_large_mdot_-3_alphaCE_0.50_alphaTH_0_ce_applied.csv
# 153 / 162 raw_models/sdBShortP_large_jdotp_30_alphaCE_0.70_alphaTH_0_ce_applied.csv
# 154 / 162 raw_models/sdBShortP_large_jdotp_1_alphaCE_1.00_alphaTH_0_ce_applied.csv
# 155 / 162 raw_models/sdBShortP_large_mdot_-3_alphaCE_0.10_alphaTH_0.10_ce_applied.csv
# 156 / 162 raw_models/sdBShortP_large_jdotp_30_alphaCE_0.50_alphaTH_0_ce_applied.csv
# 157 / 162 raw_models/sdBShortP_large_jdotp_100_alphaCE_0.30_alphaTH_0_ce_applied.csv
# 158 / 162 raw_models/sdBShortP_large_jdotp_3_alphaCE_0.70_alphaTH_0.70_ce_applied.csv
# 159 / 162 raw_models/sdBShortP_large_mdot_-3_alphaCE_1.00_alphaTH_0_ce_applied.csv
# 160 / 162 raw_models/sdBShortP_large_mdot_0_alphaCE_0.10_alphaTH_0.10_ce_applied.csv
# 161 / 162 raw_models/sdBShortP_large_mdot_-3_alphaCE_0.20_alphaTH_0.20_ce_applied.csv
# 162 / 162 raw_models/sdBShortP_large_jdotp_30_alphaCE_0.70_alphaTH_0.70_ce_applied.csv
